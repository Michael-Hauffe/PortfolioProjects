# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv(r'C:\Users\Administrator\Desktop\Data Analyst Portfolio Projects\Python Movies\movies.csv\movies.csv')

# %%
#looking at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
#checking for missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#Data types for columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Drop null values then changed the data type of budget and gross to interger
df = df.dropna()

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
df['budget_to_gross_ratio'] = df['budget']/df['gross']
df.sort_values(by='budget_to_gross_ratio', ascending=False)
# Out:
#                             name     rating   genre  year  \
# 3203                  Trojan War      PG-13  Comedy  1997
# 3681                Ginger Snaps  Not Rated   Drama  2000
# 2434  Philadelphia Experiment II      PG-13  Action  1993
# 1898    The Lovers on the Bridge          R   Drama  1991
# 3413                      Savior          R   Drama  1998
# ...                          ...        ...     ...   ...
# 5154                        Once          R   Drama  2007
# 2093                 El Mariachi          R  Action  1992
# 6815                 The Gallows          R  Horror  2015
# 3459     The Blair Witch Project          R  Horror  1999
# 5114         Paranormal Activity          R  Horror  2007
#
#                                released  score     votes             director  \
# 3203           October 1, 1997 (Brazil)    5.7    5800.0         George Huang
# 3681              May 11, 2001 (Canada)    6.8   43000.0         John Fawcett
# 2434         June 4, 1994 (South Korea)    4.5    1900.0     Stephen Cornwell
# 1898       July 2, 1999 (United States)    7.6   13000.0           Leos Carax
# 3413  November 20, 1998 (United States)    7.3   11000.0  Predrag Antonijevic
# ...                                 ...    ...       ...                  ...
# 5154      June 15, 2007 (United States)    7.8  112000.0          John Carney
# 2093  February 26, 1993 (United States)    6.9   64000.0     Robert Rodriguez
# 6815      July 10, 2015 (United States)    4.3   20000.0         Travis Cluff
# 3459      July 30, 1999 (United States)    6.5  239000.0        Daniel Myrick
# 5114   October 16, 2009 (United States)    6.3  225000.0            Oren Peli
#
#                   writer               star        country    budget  \
# 3203           Andy Burg       Will Friedle  United States  15000000
# 3681        Karen Walton      Emily Perkins         Canada   5000000
# 2434  Wallace C. Bennett       Brad Johnson  United States   5000000
# 1898          Leos Carax   Juliette Binoche         France  28000000
# 3413          Robert Orr       Dennis Quaid  United States  10000000
# ...                  ...                ...            ...       ...
# 5154         John Carney       Glen Hansard        Ireland    150000
# 2093    Robert Rodriguez    Carlos Gallardo         Mexico      7000
# 6815        Chris Lofing      Reese Mishler  United States    100000
# 3459       Daniel Myrick    Heather Donahue  United States     60000
# 5114           Oren Peli  Katie Featherston  United States     15000
#
#           gross                            company  runtime  yearcorrect  \
# 3203        309                           Daybreak     85.0         1997
# 3681       2554          Copperheart Entertainment    108.0         2001
# 2434       2970                   Trimark Pictures     97.0         1994
# 1898      29679                           Films A2    125.0         1999
# 3413      14328  Initial Entertainment Group (IEG)    103.0         1998
# ...         ...                                ...      ...          ...
# 5154   20936722           Bórd Scannán na hÉireann     86.0         2007
# 2093    2040920                  Columbia Pictures     81.0         1993
# 6815   42964410                    New Line Cinema     81.0         2015
# 3459  248639099                        Haxan Films     81.0         1999
# 5114  193355800                       Solana Films     86.0         2009
#
#       budget_to_gross_ratio
# 3203           48543.689320
# 3681            1957.713391
# 2434            1683.501684
# 1898             943.428013
# 3413             697.934115
# ...                     ...
# 5154               0.007164
# 2093               0.003430
# 6815               0.002328
# 3459               0.000241
# 5114               0.000078
#
# [5421 rows x 17 columns]

# %%
df['profit'] = df['gross']-df['budget']
df.sort_values(by='profit', ascending=False)
# Out:
#                                             name rating      genre  year  \
# 5445                                      Avatar  PG-13     Action  2009
# 7445                           Avengers: Endgame  PG-13     Action  2019
# 3045                                     Titanic  PG-13      Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# ...                                          ...    ...        ...   ...
# 2700                            Cutthroat Island  PG-13     Action  1995
# 6023                       Jin ling shi san chai      R      Drama  2011
# 4218                The Adventures of Pluto Nash  PG-13     Action  2002
# 3485                            The 13th Warrior      R     Action  1999
# 7465                                The Irishman      R  Biography  2019
#
#                                released  score      votes         director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0    James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0    Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0    James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0      J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0    Anthony Russo
# ...                                 ...    ...        ...              ...
# 2700  December 22, 1995 (United States)    5.7    27000.0     Renny Harlin
# 6023          December 16, 2011 (China)    7.6    51000.0      Yimou Zhang
# 4218    August 16, 2002 (United States)    3.8    25000.0    Ron Underwood
# 3485    August 27, 1999 (United States)    6.6   119000.0   John McTiernan
# 7465  November 27, 2019 (United States)    7.8   344000.0  Martin Scorsese
#
#                      writer               star        country     budget  \
# 5445          James Cameron    Sam Worthington  United States  237000000
# 7445     Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045          James Cameron  Leonardo DiCaprio  United States  200000000
# 6663        Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244     Christopher Markus  Robert Downey Jr.  United States  321000000
# ...                     ...                ...            ...        ...
# 2700  Michael Frost Beckner        Geena Davis         France   98000000
# 6023               Heng Liu     Christian Bale          China   94000000
# 4218          Neil Cuthbert       Eddie Murphy  United States  100000000
# 3485       Michael Crichton   Antonio Banderas  United States  160000000
# 7465        Steven Zaillian     Robert De Niro  United States  159000000
#
#            gross                     company  runtime  yearcorrect  \
# 5445  2847246203       Twentieth Century Fox    162.0         2009
# 7445  2797501328              Marvel Studios    181.0         2019
# 3045  2201647264       Twentieth Century Fox    194.0         1997
# 6663  2069521700                   Lucasfilm    138.0         2015
# 7244  2048359754              Marvel Studios    149.0         2018
# ...          ...                         ...      ...          ...
# 2700    10017322  Beckner/Gorman Productions    124.0         1995
# 6023     2855644    Beijing New Picture Film    146.0         2011
# 4218     7103973   Castle Rock Entertainment     95.0         2002
# 3485    61698899         Touchstone Pictures    102.0         1999
# 7465      968853         Tribeca Productions    209.0         2019
#
#       budget_to_gross_ratio      profit
# 5445               0.083238  2610246203
# 7445               0.127256  2441501328
# 3045               0.090841  2001647264
# 6663               0.118385  1824521700
# 7244               0.156711  1727359754
# ...                     ...         ...
# 2700               9.783054   -87982678
# 6023              32.917268   -91144356
# 4218              14.076630   -92896027
# 3485               2.593239   -98301101
# 7465             164.111583  -158031147
#
# [5421 rows x 18 columns]

# %%
#Drop any duplicates
df['company'].drop_duplicates().sort_values()
# Out:
# 4345        "DIA" Productions GmbH & Co. KG
# 7525    "Weathering With You" Film Partners
# 3024                        .406 Production
# 3748                     1+2 Seisaku Iinkai
# 5813                        10 West Studios
#                        ...
# 4007                               i5 Films
# 6412               iDeal Partners Film Fund
# 5664                            micro_scope
# 7129                                thefyzz
# 408                                     NaN
# Name: company, Length: 2386, dtype: object

# %%
#Scatter plot with budget vs gross revenue

plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.ylabel('Gross Earnings')
plt.xlabel('Budget')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime  yearcorrect  \
# 5445  2847246203  Twentieth Century Fox    162.0         2009
# 7445  2797501328         Marvel Studios    181.0         2019
# 3045  2201647264  Twentieth Century Fox    194.0         1997
# 6663  2069521700              Lucasfilm    138.0         2015
# 7244  2048359754         Marvel Studios    149.0         2018
#
#       budget_to_gross_ratio      profit
# 5445               0.083238  2610246203
# 7445               0.127256  2441501328
# 3045               0.090841  2001647264
# 6663               0.118385  1824521700
# 7244               0.156711  1727359754

# %%
#plot budget vs gross using seaborn
sns.regplot(x='budget',y='gross', data=df , scatter_kws={'color':'red'},line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson',numeric_only=True)
# Out:
#                            year     score     votes    budget     gross  \
# year                   1.000000  0.056386  0.206021  0.327722  0.274321
# score                  0.056386  1.000000  0.474256  0.072001  0.222556
# votes                  0.206021  0.474256  1.000000  0.439675  0.614751
# budget                 0.327722  0.072001  0.439675  1.000000  0.740247
# gross                  0.274321  0.222556  0.614751  0.740247  1.000000
# runtime                0.075077  0.414068  0.352303  0.318695  0.275796
# yearcorrect            0.998726  0.061923  0.203098  0.320312  0.268721
# budget_to_gross_ratio -0.008327 -0.012515 -0.011096 -0.009937 -0.010735
# profit                 0.237456  0.243340  0.609203  0.610530  0.984428
#
#                         runtime  yearcorrect  budget_to_gross_ratio    profit
# year                   0.075077     0.998726              -0.008327  0.237456
# score                  0.414068     0.061923              -0.012515  0.243340
# votes                  0.352303     0.203098              -0.011096  0.609203
# budget                 0.318695     0.320312              -0.009937  0.610530
# gross                  0.275796     0.268721              -0.010735  0.984428
# runtime                1.000000     0.075294              -0.018810  0.241554
# yearcorrect            0.075294     1.000000              -0.008001  0.232797
# budget_to_gross_ratio -0.018810    -0.008001               1.000000 -0.010048
# profit                 0.241554     0.232797              -0.010048  1.000000

# %%
correlation_matrix = df.corr(method='pearson',numeric_only=True)
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.ylabel('Movie Features')
plt.xlabel('Movie Features')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Look at Company
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime  yearcorrect  \
# 5445  2847246203  Twentieth Century Fox    162.0         2009
# 7445  2797501328         Marvel Studios    181.0         2019
# 3045  2201647264  Twentieth Century Fox    194.0         1997
# 6663  2069521700              Lucasfilm    138.0         2015
# 7244  2048359754         Marvel Studios    149.0         2018
#
#       budget_to_gross_ratio      profit
# 5445               0.083238  2610246203
# 7445               0.127256  2441501328
# 3045               0.090841  2001647264
# 6663               0.118385  1824521700
# 7244               0.156711  1727359754

# %%
df_Numbered = df
for col_name in df_Numbered.columns:
    if(df_Numbered[col_name].dtype == 'object'):
        df_Numbered[col_name] = df_Numbered[col_name].astype('category')
        df_Numbered[col_name] = df_Numbered[col_name].cat.codes
df_Numbered
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
#       star  country     budget       gross  company  runtime  yearcorrect  \
# 5445  1534       47  237000000  2847246203     1382    162.0         2009
# 7445  1470       47  356000000  2797501328      983    181.0         2019
# 3045  1073       47  200000000  2201647264     1382    194.0         1997
# 6663   356       47  245000000  2069521700      945    138.0         2015
# 7244  1470       47  321000000  2048359754      983    149.0         2018
# ...    ...      ...        ...         ...      ...      ...          ...
# 5640  1498       47    3000000        5073     1385     96.0         2015
# 2434   186       47    5000000        2970     1376     97.0         1994
# 3681   527        6    5000000        2554      466    108.0         2001
# 272   1473       47     800000        2270      582     85.0         1982
# 3203  1811       47   15000000         309      504     85.0         1997
#
#       budget_to_gross_ratio      profit
# 5445               0.083238  2610246203
# 7445               0.127256  2441501328
# 3045               0.090841  2001647264
# 6663               0.118385  1824521700
# 7244               0.156711  1727359754
# ...                     ...         ...
# 5640             591.366056    -2994927
# 2434            1683.501684    -4997030
# 3681            1957.713391    -4997446
# 272              352.422907     -797730
# 3203           48543.689320   -14999691
#
# [5421 rows x 18 columns]

# %%
correlation_matrix = df_Numbered.corr(method='pearson',numeric_only=True)
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.ylabel('Movie Features')
plt.xlabel('Movie Features')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pd.set_option('display.max_rows', None)
correlation_mat = df_Numbered.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name                   name                     1.000000
#                        rating                  -0.029234
#                        genre                    0.010996
#                        year                     0.025542
#                        released                -0.006152
#                        score                    0.014450
#                        votes                    0.012615
#                        director                 0.015246
#                        writer                   0.012880
#                        star                    -0.006882
#                        country                 -0.025490
#                        budget                   0.023392
#                        gross                    0.005639
#                        company                  0.021697
#                        runtime                  0.010850
#                        yearcorrect              0.025542
#                        budget_to_gross_ratio    0.019841
#                        profit                   0.000526
# rating                 name                    -0.029234
#                        rating                   1.000000
#                        genre                    0.147796
#                        year                     0.019499
#                        released                 0.018083
#                        score                    0.065983
#                        votes                    0.006031
#                        director                 0.014656
#                        writer                  -0.003149
#                        star                     0.009196
#                        country                  0.008230
#                        budget                  -0.203946
#                        gross                   -0.181906
#                        company                 -0.092357
#                        runtime                  0.140792
#                        yearcorrect              0.022021
#                        budget_to_gross_ratio   -0.002920
#                        profit                  -0.160956
# genre                  name                     0.010996
#                        rating                   0.147796
#                        genre                    1.000000
#                        year                    -0.073167
#                        released                 0.022142
#                        score                    0.035106
#                        votes                   -0.135990
#                        director                -0.008553
#                        writer                   0.017578
#                        star                     0.003341
#                        country                 -0.009164
#                        budget                  -0.368523
#                        gross                   -0.244101
#                        company                 -0.071334
#                        runtime                 -0.059237
#                        yearcorrect             -0.069147
#                        budget_to_gross_ratio    0.005495
#                        profit                  -0.191190
# year                   name                     0.025542
#                        rating                   0.019499
#                        genre                   -0.073167
#                        year                     1.000000
#                        released                -0.001740
#                        score                    0.056386
#                        votes                    0.206021
#                        director                -0.038354
#                        writer                  -0.025908
#                        star                    -0.032157
#                        country                 -0.066748
#                        budget                   0.327722
#                        gross                    0.274321
#                        company                 -0.014333
#                        runtime                  0.075077
#                        yearcorrect              0.998726
#                        budget_to_gross_ratio   -0.008327
#                        profit                   0.237456
# released               name                    -0.006152
#                        rating                   0.018083
#                        genre                    0.022142
#                        year                    -0.001740
#                        released                 1.000000
#                        score                    0.045874
#                        votes                    0.028833
#                        director                 0.002308
#                        writer                   0.008072
#                        star                     0.015706
#                        country                 -0.017228
#                        budget                   0.019952
#                        gross                    0.008501
#                        company                 -0.002407
#                        runtime                  0.008975
#                        yearcorrect             -0.005989
#                        budget_to_gross_ratio    0.016658
#                        profit                   0.004797
# score                  name                     0.014450
#                        rating                   0.065983
#                        genre                    0.035106
#                        year                     0.056386
#                        released                 0.045874
#                        score                    1.000000
#                        votes                    0.474256
#                        director                 0.005413
#                        writer                   0.012843
#                        star                     0.007296
#                        country                 -0.043051
#                        budget                   0.072001
#                        gross                    0.222556
#                        company                  0.020656
#                        runtime                  0.414068
#                        yearcorrect              0.061923
#                        budget_to_gross_ratio   -0.012515
#                        profit                   0.243340
# votes                  name                     0.012615
#                        rating                   0.006031
#                        genre                   -0.135990
#                        year                     0.206021
#                        released                 0.028833
#                        score                    0.474256
#                        votes                    1.000000
#                        director                -0.010376
#                        writer                  -0.005316
#                        star                    -0.017638
#                        country                  0.041551
#                        budget                   0.439675
#                        gross                    0.614751
#                        company                  0.118470
#                        runtime                  0.352303
#                        yearcorrect              0.203098
#                        budget_to_gross_ratio   -0.011096
#                        profit                   0.609203
# director               name                     0.015246
#                        rating                   0.014656
#                        genre                   -0.008553
#                        year                    -0.038354
#                        released                 0.002308
#                        score                    0.005413
#                        votes                   -0.010376
#                        director                 1.000000
#                        writer                   0.261735
#                        star                     0.036593
#                        country                  0.011133
#                        budget                  -0.009662
#                        gross                   -0.029560
#                        company                 -0.008223
#                        runtime                  0.017433
#                        yearcorrect             -0.037371
#                        budget_to_gross_ratio   -0.008393
#                        profit                  -0.032295
# writer                 name                     0.012880
#                        rating                  -0.003149
#                        genre                    0.017578
#                        year                    -0.025908
#                        released                 0.008072
#                        score                    0.012843
#                        votes                   -0.005316
#                        director                 0.261735
#                        writer                   1.000000
#                        star                     0.018520
#                        country                  0.022488
#                        budget                  -0.039466
#                        gross                   -0.035885
#                        company                 -0.003697
#                        runtime                 -0.017561
#                        yearcorrect             -0.025495
#                        budget_to_gross_ratio   -0.019449
#                        profit                  -0.031953
# star                   name                    -0.006882
#                        rating                   0.009196
#                        genre                    0.003341
#                        year                    -0.032157
#                        released                 0.015706
#                        score                    0.007296
#                        votes                   -0.017638
#                        director                 0.036593
#                        writer                   0.018520
#                        star                     1.000000
#                        country                 -0.009990
#                        budget                  -0.021473
#                        gross                   -0.000004
#                        company                  0.014082
#                        runtime                  0.010108
#                        yearcorrect             -0.032687
#                        budget_to_gross_ratio    0.021306
#                        profit                   0.005610
# country                name                    -0.025490
#                        rating                   0.008230
#                        genre                   -0.009164
#                        year                    -0.066748
#                        released                -0.017228
#                        score                   -0.043051
#                        votes                    0.041551
#                        director                 0.011133
#                        writer                   0.022488
#                        star                    -0.009990
#                        country                  1.000000
#                        budget                   0.052977
#                        gross                    0.060078
#                        company                  0.048569
#                        runtime                 -0.034477
#                        yearcorrect             -0.073569
#                        budget_to_gross_ratio    0.001796
#                        profit                   0.056919
# budget                 name                     0.023392
#                        rating                  -0.203946
#                        genre                   -0.368523
#                        year                     0.327722
#                        released                 0.019952
#                        score                    0.072001
#                        votes                    0.439675
#                        director                -0.009662
#                        writer                  -0.039466
#                        star                    -0.021473
#                        country                  0.052977
#                        budget                   1.000000
#                        gross                    0.740247
#                        company                  0.170235
#                        runtime                  0.318695
#                        yearcorrect              0.320312
#                        budget_to_gross_ratio   -0.009937
#                        profit                   0.610530
# gross                  name                     0.005639
#                        rating                  -0.181906
#                        genre                   -0.244101
#                        year                     0.274321
#                        released                 0.008501
#                        score                    0.222556
#                        votes                    0.614751
#                        director                -0.029560
#                        writer                  -0.035885
#                        star                    -0.000004
#                        country                  0.060078
#                        budget                   0.740247
#                        gross                    1.000000
#                        company                  0.149553
#                        runtime                  0.275796
#                        yearcorrect              0.268721
#                        budget_to_gross_ratio   -0.010735
#                        profit                   0.984428
# company                name                     0.021697
#                        rating                  -0.092357
#                        genre                   -0.071334
#                        year                    -0.014333
#                        released                -0.002407
#                        score                    0.020656
#                        votes                    0.118470
#                        director                -0.008223
#                        writer                  -0.003697
#                        star                     0.014082
#                        country                  0.048569
#                        budget                   0.170235
#                        gross                    0.149553
#                        company                  1.000000
#                        runtime                  0.037585
#                        yearcorrect             -0.018806
#                        budget_to_gross_ratio   -0.014497
#                        profit                   0.131659
# runtime                name                     0.010850
#                        rating                   0.140792
#                        genre                   -0.059237
#                        year                     0.075077
#                        released                 0.008975
#                        score                    0.414068
#                        votes                    0.352303
#                        director                 0.017433
#                        writer                  -0.017561
#                        star                     0.010108
#                        country                 -0.034477
#                        budget                   0.318695
#                        gross                    0.275796
#                        company                  0.037585
#                        runtime                  1.000000
#                        yearcorrect              0.075294
#                        budget_to_gross_ratio   -0.018810
#                        profit                   0.241554
# yearcorrect            name                     0.025542
#                        rating                   0.022021
#                        genre                   -0.069147
#                        year                     0.998726
#                        released                -0.005989
#                        score                    0.061923
#                        votes                    0.203098
#                        director                -0.037371
#                        writer                  -0.025495
#                        star                    -0.032687
#                        country                 -0.073569
#                        budget                   0.320312
#                        gross                    0.268721
#                        company                 -0.018806
#                        runtime                  0.075294
#                        yearcorrect              1.000000
#                        budget_to_gross_ratio   -0.008001
#                        profit                   0.232797
# budget_to_gross_ratio  name                     0.019841
#                        rating                  -0.002920
#                        genre                    0.005495
#                        year                    -0.008327
#                        released                 0.016658
#                        score                   -0.012515
#                        votes                   -0.011096
#                        director                -0.008393
#                        writer                  -0.019449
#                        star                     0.021306
#                        country                  0.001796
#                        budget                  -0.009937
#                        gross                   -0.010735
#                        company                 -0.014497
#                        runtime                 -0.018810
#                        yearcorrect             -0.008001
#                        budget_to_gross_ratio    1.000000
#                        profit                  -0.010048
# profit                 name                     0.000526
#                        rating                  -0.160956
#                        genre                   -0.191190
#                        year                     0.237456
#                        released                 0.004797
#                        score                    0.243340
#                        votes                    0.609203
#                        director                -0.032295
#                        writer                  -0.031953
#                        star                     0.005610
#                        country                  0.056919
#                        budget                   0.610530
#                        gross                    0.984428
#                        company                  0.131659
#                        runtime                  0.241554
#                        yearcorrect              0.232797
#                        budget_to_gross_ratio   -0.010048
#                        profit                   1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs
# Out:
# name                   name                     1.000000
# star                   star                     1.000000
# year                   year                     1.000000
# released               released                 1.000000
# score                  score                    1.000000
# votes                  votes                    1.000000
# director               director                 1.000000
# writer                 writer                   1.000000
# country                country                  1.000000
# rating                 rating                   1.000000
# budget                 budget                   1.000000
# gross                  gross                    1.000000
# company                company                  1.000000
# runtime                runtime                  1.000000
# yearcorrect            yearcorrect              1.000000
# budget_to_gross_ratio  budget_to_gross_ratio    1.000000
# genre                  genre                    1.000000
# profit                 profit                   1.000000
# yearcorrect            year                     0.998726
# year                   yearcorrect              0.998726
# profit                 gross                    0.984428
# gross                  profit                   0.984428
# budget                 gross                    0.740247
# gross                  budget                   0.740247
#                        votes                    0.614751
# votes                  gross                    0.614751
# budget                 profit                   0.610530
# profit                 budget                   0.610530
#                        votes                    0.609203
# votes                  profit                   0.609203
#                        score                    0.474256
# score                  votes                    0.474256
# budget                 votes                    0.439675
# votes                  budget                   0.439675
# score                  runtime                  0.414068
# runtime                score                    0.414068
#                        votes                    0.352303
# votes                  runtime                  0.352303
# year                   budget                   0.327722
# budget                 year                     0.327722
#                        yearcorrect              0.320312
# yearcorrect            budget                   0.320312
# runtime                budget                   0.318695
# budget                 runtime                  0.318695
# runtime                gross                    0.275796
# gross                  runtime                  0.275796
# year                   gross                    0.274321
# gross                  year                     0.274321
#                        yearcorrect              0.268721
# yearcorrect            gross                    0.268721
# writer                 director                 0.261735
# director               writer                   0.261735
# score                  profit                   0.243340
# profit                 score                    0.243340
# runtime                profit                   0.241554
# profit                 runtime                  0.241554
# year                   profit                   0.237456
# profit                 year                     0.237456
#                        yearcorrect              0.232797
# yearcorrect            profit                   0.232797
# gross                  score                    0.222556
# score                  gross                    0.222556
# votes                  year                     0.206021
# year                   votes                    0.206021
# yearcorrect            votes                    0.203098
# votes                  yearcorrect              0.203098
# company                budget                   0.170235
# budget                 company                  0.170235
# gross                  company                  0.149553
# company                gross                    0.149553
# genre                  rating                   0.147796
# rating                 genre                    0.147796
# runtime                rating                   0.140792
# rating                 runtime                  0.140792
# company                profit                   0.131659
# profit                 company                  0.131659
# company                votes                    0.118470
# votes                  company                  0.118470
# yearcorrect            runtime                  0.075294
# runtime                yearcorrect              0.075294
# year                   runtime                  0.075077
# runtime                year                     0.075077
# budget                 score                    0.072001
# score                  budget                   0.072001
# rating                 score                    0.065983
# score                  rating                   0.065983
# yearcorrect            score                    0.061923
# score                  yearcorrect              0.061923
# gross                  country                  0.060078
# country                gross                    0.060078
#                        profit                   0.056919
# profit                 country                  0.056919
# score                  year                     0.056386
# year                   score                    0.056386
# country                budget                   0.052977
# budget                 country                  0.052977
# country                company                  0.048569
# company                country                  0.048569
# score                  released                 0.045874
# released               score                    0.045874
# country                votes                    0.041551
# votes                  country                  0.041551
# company                runtime                  0.037585
# runtime                company                  0.037585
# star                   director                 0.036593
# director               star                     0.036593
# score                  genre                    0.035106
# genre                  score                    0.035106
# votes                  released                 0.028833
# released               votes                    0.028833
# name                   year                     0.025542
# year                   name                     0.025542
# yearcorrect            name                     0.025542
# name                   yearcorrect              0.025542
#                        budget                   0.023392
# budget                 name                     0.023392
# country                writer                   0.022488
# writer                 country                  0.022488
# released               genre                    0.022142
# genre                  released                 0.022142
# rating                 yearcorrect              0.022021
# yearcorrect            rating                   0.022021
# company                name                     0.021697
# name                   company                  0.021697
# budget_to_gross_ratio  star                     0.021306
# star                   budget_to_gross_ratio    0.021306
# company                score                    0.020656
# score                  company                  0.020656
# budget                 released                 0.019952
# released               budget                   0.019952
# budget_to_gross_ratio  name                     0.019841
# name                   budget_to_gross_ratio    0.019841
# rating                 year                     0.019499
# year                   rating                   0.019499
# star                   writer                   0.018520
# writer                 star                     0.018520
# released               rating                   0.018083
# rating                 released                 0.018083
# genre                  writer                   0.017578
# writer                 genre                    0.017578
# director               runtime                  0.017433
# runtime                director                 0.017433
# released               budget_to_gross_ratio    0.016658
# budget_to_gross_ratio  released                 0.016658
# star                   released                 0.015706
# released               star                     0.015706
# name                   director                 0.015246
# director               name                     0.015246
# rating                 director                 0.014656
# director               rating                   0.014656
# score                  name                     0.014450
# name                   score                    0.014450
# star                   company                  0.014082
# company                star                     0.014082
# name                   writer                   0.012880
# writer                 name                     0.012880
#                        score                    0.012843
# score                  writer                   0.012843
# name                   votes                    0.012615
# votes                  name                     0.012615
# country                director                 0.011133
# director               country                  0.011133
# genre                  name                     0.010996
# name                   genre                    0.010996
# runtime                name                     0.010850
# name                   runtime                  0.010850
# runtime                star                     0.010108
# star                   runtime                  0.010108
# rating                 star                     0.009196
# star                   rating                   0.009196
# runtime                released                 0.008975
# released               runtime                  0.008975
# gross                  released                 0.008501
# released               gross                    0.008501
# rating                 country                  0.008230
# country                rating                   0.008230
# writer                 released                 0.008072
# released               writer                   0.008072
# star                   score                    0.007296
# score                  star                     0.007296
# rating                 votes                    0.006031
# votes                  rating                   0.006031
# gross                  name                     0.005639
# name                   gross                    0.005639
# star                   profit                   0.005610
# profit                 star                     0.005610
# genre                  budget_to_gross_ratio    0.005495
# budget_to_gross_ratio  genre                    0.005495
# score                  director                 0.005413
# director               score                    0.005413
# profit                 released                 0.004797
# released               profit                   0.004797
# genre                  star                     0.003341
# star                   genre                    0.003341
# director               released                 0.002308
# released               director                 0.002308
# budget_to_gross_ratio  country                  0.001796
# country                budget_to_gross_ratio    0.001796
# profit                 name                     0.000526
# name                   profit                   0.000526
# star                   gross                   -0.000004
# gross                  star                    -0.000004
# year                   released                -0.001740
# released               year                    -0.001740
#                        company                 -0.002407
# company                released                -0.002407
# budget_to_gross_ratio  rating                  -0.002920
# rating                 budget_to_gross_ratio   -0.002920
#                        writer                  -0.003149
# writer                 rating                  -0.003149
# company                writer                  -0.003697
# writer                 company                 -0.003697
#                        votes                   -0.005316
# votes                  writer                  -0.005316
# yearcorrect            released                -0.005989
# released               yearcorrect             -0.005989
# name                   released                -0.006152
# released               name                    -0.006152
# name                   star                    -0.006882
# star                   name                    -0.006882
# yearcorrect            budget_to_gross_ratio   -0.008001
# budget_to_gross_ratio  yearcorrect             -0.008001
# company                director                -0.008223
# director               company                 -0.008223
# year                   budget_to_gross_ratio   -0.008327
# budget_to_gross_ratio  year                    -0.008327
#                        director                -0.008393
# director               budget_to_gross_ratio   -0.008393
# genre                  director                -0.008553
# director               genre                   -0.008553
# genre                  country                 -0.009164
# country                genre                   -0.009164
# budget                 director                -0.009662
# director               budget                  -0.009662
# budget_to_gross_ratio  budget                  -0.009937
# budget                 budget_to_gross_ratio   -0.009937
# star                   country                 -0.009990
# country                star                    -0.009990
# profit                 budget_to_gross_ratio   -0.010048
# budget_to_gross_ratio  profit                  -0.010048
# votes                  director                -0.010376
# director               votes                   -0.010376
# budget_to_gross_ratio  gross                   -0.010735
# gross                  budget_to_gross_ratio   -0.010735
# budget_to_gross_ratio  votes                   -0.011096
# votes                  budget_to_gross_ratio   -0.011096
# score                  budget_to_gross_ratio   -0.012515
# budget_to_gross_ratio  score                   -0.012515
# company                year                    -0.014333
# year                   company                 -0.014333
# company                budget_to_gross_ratio   -0.014497
# budget_to_gross_ratio  company                 -0.014497
# released               country                 -0.017228
# country                released                -0.017228
# writer                 runtime                 -0.017561
# runtime                writer                  -0.017561
# votes                  star                    -0.017638
# star                   votes                   -0.017638
# yearcorrect            company                 -0.018806
# company                yearcorrect             -0.018806
# budget_to_gross_ratio  runtime                 -0.018810
# runtime                budget_to_gross_ratio   -0.018810
# budget_to_gross_ratio  writer                  -0.019449
# writer                 budget_to_gross_ratio   -0.019449
# budget                 star                    -0.021473
# star                   budget                  -0.021473
# name                   country                 -0.025490
# country                name                    -0.025490
# yearcorrect            writer                  -0.025495
# writer                 yearcorrect             -0.025495
#                        year                    -0.025908
# year                   writer                  -0.025908
# rating                 name                    -0.029234
# name                   rating                  -0.029234
# gross                  director                -0.029560
# director               gross                   -0.029560
# profit                 writer                  -0.031953
# writer                 profit                  -0.031953
# star                   year                    -0.032157
# year                   star                    -0.032157
# director               profit                  -0.032295
# profit                 director                -0.032295
# yearcorrect            star                    -0.032687
# star                   yearcorrect             -0.032687
# runtime                country                 -0.034477
# country                runtime                 -0.034477
# gross                  writer                  -0.035885
# writer                 gross                   -0.035885
# director               yearcorrect             -0.037371
# yearcorrect            director                -0.037371
# year                   director                -0.038354
# director               year                    -0.038354
# budget                 writer                  -0.039466
# writer                 budget                  -0.039466
# score                  country                 -0.043051
# country                score                   -0.043051
# genre                  runtime                 -0.059237
# runtime                genre                   -0.059237
# year                   country                 -0.066748
# country                year                    -0.066748
# genre                  yearcorrect             -0.069147
# yearcorrect            genre                   -0.069147
# genre                  company                 -0.071334
# company                genre                   -0.071334
# year                   genre                   -0.073167
# genre                  year                    -0.073167
# yearcorrect            country                 -0.073569
# country                yearcorrect             -0.073569
# company                rating                  -0.092357
# rating                 company                 -0.092357
# genre                  votes                   -0.135990
# votes                  genre                   -0.135990
# profit                 rating                  -0.160956
# rating                 profit                  -0.160956
# gross                  rating                  -0.181906
# rating                 gross                   -0.181906
# genre                  profit                  -0.191190
# profit                 genre                   -0.191190
# budget                 rating                  -0.203946
# rating                 budget                  -0.203946
# genre                  gross                   -0.244101
# gross                  genre                   -0.244101
# genre                  budget                  -0.368523
# budget                 genre                   -0.368523
# dtype: float64

# %%
#Budget and Gross have the highest correlation among variables that are not related by definition
#The correlation between the number of votes received and profit is higher than the correlation between the score of votes received and profit
high_corr = sorted_pairs[sorted_pairs > 0.5]
high_corr
# Out:
# name                   name                     1.000000
# star                   star                     1.000000
# year                   year                     1.000000
# released               released                 1.000000
# score                  score                    1.000000
# votes                  votes                    1.000000
# director               director                 1.000000
# writer                 writer                   1.000000
# country                country                  1.000000
# rating                 rating                   1.000000
# budget                 budget                   1.000000
# gross                  gross                    1.000000
# company                company                  1.000000
# runtime                runtime                  1.000000
# yearcorrect            yearcorrect              1.000000
# budget_to_gross_ratio  budget_to_gross_ratio    1.000000
# genre                  genre                    1.000000
# profit                 profit                   1.000000
# yearcorrect            year                     0.998726
# year                   yearcorrect              0.998726
# profit                 gross                    0.984428
# gross                  profit                   0.984428
# budget                 gross                    0.740247
# gross                  budget                   0.740247
#                        votes                    0.614751
# votes                  gross                    0.614751
# budget                 profit                   0.610530
# profit                 budget                   0.610530
#                        votes                    0.609203
# votes                  profit                   0.609203
# dtype: float64
